# %%
import os
import numpy as np
import matplotlib
import matplotlib.pyplot as plt

# %matplotlib inline  

cwd = os.getcwd()

# %%
f = open("../data/OSULeaf_TRAIN", "r")

x_label = []
x_feature = []

for i, line in enumerate(f):
    line = line.strip().split(" ")
    line = list(filter(lambda x: len(x) > 0, line))
    
    x_label.append(float(line[0]))
    x_feature.append(line[1:])
    
x_label = np.array(x_label, np.int32)
x_feature = np.array(x_feature, np.float)

# %%
def plot_class(ax, clazz):
    x_idx = x_label == clazz
    ax.set(title='Class ' + str(clazz))
    ax.grid()
    for x in x_feature[x_idx]:
        ax.plot(x, 'C' + str(clazz % 10))

# %%
fig, axes = plt.subplots(3, 3, figsize=(12, 12))
for i in range(3):
    for j in range(3):
        plot_class(axes[i, j] ,i*3+j+1)
plt.show()

# %%
x_label
# Out:
# array([6, 5, 2, 1, 3, 3, 2, 3, 4, 5, 1, 2, 3, 5, 2, 2, 2, 4, 4, 1, 5, 4,
#        4, 4, 1, 6, 3, 5, 1, 4, 4, 6, 5, 5, 2, 5, 4, 1, 4, 2, 5, 5, 4, 5,
#        5, 3, 1, 3, 2, 4, 3, 1, 3, 5, 4, 2, 3, 4, 6, 4, 1, 4, 4, 1, 4, 3,
#        4, 1, 2, 1, 4, 5, 5, 1, 1, 4, 5, 4, 4, 4, 4, 4, 2, 3, 2, 3, 1, 1,
#        4, 6, 5, 4, 1, 3, 2, 2, 5, 4, 3, 2, 5, 4, 1, 4, 4, 3, 4, 5, 4, 3,
#        6, 4, 4, 1, 3, 3, 5, 5, 4, 1, 4, 6, 6, 1, 2, 3, 1, 5, 5, 4, 4, 5,
#        1, 3, 3, 2, 1, 5, 4, 3, 3, 3, 5, 4, 2, 4, 4, 4, 2, 4, 3, 6, 5, 2,
#        2, 6, 6, 4, 1, 2, 2, 3, 1, 5, 3, 3, 5, 5, 4, 6, 4, 5, 1, 1, 5, 4,
#        1, 6, 2, 2, 4, 6, 4, 4, 5, 3, 1, 2, 1, 1, 5, 2, 3, 5, 6, 1, 3, 1,
#        2, 3], dtype=int32)

# %%
plt.plot(x_feature[0])

# %%
plt.plot(x_feature[16])
